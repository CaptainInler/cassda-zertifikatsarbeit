# %% [markdown]
# # Data preparation
# In diesem Notebook wird versucht, aus den Daten der [Strassennamen](https://data.bs.ch/explore/dataset/100189/information/) des Kanton Basel-Stadt die Strassen, welche nach Personen benannt sind, zu extrahieren.

# %% [markdown]
# ---
# ## Laden der Daten

# %%
url = 'https://data.bs.ch/explore/dataset/100189/download/?format=csv&timezone=Europe/Zurich&lang=de&use_labels_for_header=true&csv_separator=%3B '

# %% [markdown]
# Daten in ein pandas-Dataframe abfüllen um eine tabelarische Übersicht über die Daten zu erhalten.
# Sollte pandas nicht installiert sein `pip install pandas`

# %%
import pandas as pd

df = pd.read_csv(url, sep=';')
df.head()
# Out:
#    Id Strasse           Strassenname  \
# 0         526          Schlüsselberg
# 1         851        Kienbergstrasse
# 2         920      Sandgrubenstrasse
# 3         474  Reichensteinerstrasse
# 4         933           Sperrstrasse
#
#                                Erklärung erste Zeile  \
# 0                       Zum Schlüssel, 1290 erstmals
# 1     Kienberg, Erhebung des Tafeljuras (743 m ü.M.)
# 2  Sandgrube, 1751 fertiggestellter Landsitz, Hin...
# 3  Reichenstein, Burgruine (12./13. Jh.) bei Arle...
# 4                        Hinweis auf das «Sperrgeld»
#
#                               Erklärung zweite Zeile  \
# 0                                erwähntes Zunfthaus
# 1              und gleichnamige Solothurner Gemeinde
# 2         auf den lokalen Sandabbau seit dem 14. Jh.
# 3  im 17. Jh. zerfallen, im 20. Jh. wieder restau...
# 4             (Einlassgebühr) am ehemaligen Bläsitor
#
#                                            Geo Shape  \
# 0  {"coordinates": [[[7.589222823644128, 47.55704...
# 1  {"coordinates": [[[7.607734652244866, 47.56154...
# 2  {"coordinates": [[[7.604715401665313, 47.56534...
# 3  {"coordinates": [[[7.583750231201226, 47.54393...
# 4  {"coordinates": [[[7.591468792945212, 47.56428...
#
#                               Geo Point Erstmals erwähnt Amtlich benannt  \
# 0  47.55696838858744,7.5899914931669015             1243            1861
# 1   47.56234486059627,7.607345597795069              NaN            1944
# 2   47.56614109591284,7.603959599528592             1820            1906
# 3   47.54423016221659,7.583998938529825              NaN            1889
# 4  47.565429802552956,7.595285320354815             1822            1864
#
#   Indextext            Kurztext
# 0       SCH       Schlüsselberg
# 1       KIE        Kienbergstr.
# 2       SAN      Sandgrubenstr.
# 3       REI  Reichensteinerstr.
# 4       SPE           Sperrstr.

# %% [markdown]
# Nach den Texten suchen, die in `Erklärung erste Zeile` eine Ziffer aufweisen

# %%
a = df.query("`Erklärung erste Zeile`.notnull()")
a.head()
# Out:
#    Id Strasse           Strassenname  \
# 0         526          Schlüsselberg
# 1         851        Kienbergstrasse
# 2         920      Sandgrubenstrasse
# 3         474  Reichensteinerstrasse
# 4         933           Sperrstrasse
#
#                                Erklärung erste Zeile  \
# 0                       Zum Schlüssel, 1290 erstmals
# 1     Kienberg, Erhebung des Tafeljuras (743 m ü.M.)
# 2  Sandgrube, 1751 fertiggestellter Landsitz, Hin...
# 3  Reichenstein, Burgruine (12./13. Jh.) bei Arle...
# 4                        Hinweis auf das «Sperrgeld»
#
#                               Erklärung zweite Zeile  \
# 0                                erwähntes Zunfthaus
# 1              und gleichnamige Solothurner Gemeinde
# 2         auf den lokalen Sandabbau seit dem 14. Jh.
# 3  im 17. Jh. zerfallen, im 20. Jh. wieder restau...
# 4             (Einlassgebühr) am ehemaligen Bläsitor
#
#                                            Geo Shape  \
# 0  {"coordinates": [[[7.589222823644128, 47.55704...
# 1  {"coordinates": [[[7.607734652244866, 47.56154...
# 2  {"coordinates": [[[7.604715401665313, 47.56534...
# 3  {"coordinates": [[[7.583750231201226, 47.54393...
# 4  {"coordinates": [[[7.591468792945212, 47.56428...
#
#                               Geo Point Erstmals erwähnt Amtlich benannt  \
# 0  47.55696838858744,7.5899914931669015             1243            1861
# 1   47.56234486059627,7.607345597795069              NaN            1944
# 2   47.56614109591284,7.603959599528592             1820            1906
# 3   47.54423016221659,7.583998938529825              NaN            1889
# 4  47.565429802552956,7.595285320354815             1822            1864
#
#   Indextext            Kurztext
# 0       SCH       Schlüsselberg
# 1       KIE        Kienbergstr.
# 2       SAN      Sandgrubenstr.
# 3       REI  Reichensteinerstr.
# 4       SPE           Sperrstr.

# %%
dfnumber = a[a["Erklärung erste Zeile"].str.contains('[0-9]')]

# %%
dfnumber.head(5)
# Out:
#    Id Strasse           Strassenname  \
# 0         526          Schlüsselberg
# 1         851        Kienbergstrasse
# 2         920      Sandgrubenstrasse
# 3         474  Reichensteinerstrasse
# 5         209        Gotthardstrasse
#
#                                Erklärung erste Zeile  \
# 0                       Zum Schlüssel, 1290 erstmals
# 1     Kienberg, Erhebung des Tafeljuras (743 m ü.M.)
# 2  Sandgrube, 1751 fertiggestellter Landsitz, Hin...
# 3  Reichenstein, Burgruine (12./13. Jh.) bei Arle...
# 5                       Gotthard (2106 m ü.M.), Pass
#
#                               Erklärung zweite Zeile  \
# 0                                erwähntes Zunfthaus
# 1              und gleichnamige Solothurner Gemeinde
# 2         auf den lokalen Sandabbau seit dem 14. Jh.
# 3  im 17. Jh. zerfallen, im 20. Jh. wieder restau...
# 5               zwischen den Kantonen Uri und Tessin
#
#                                            Geo Shape  \
# 0  {"coordinates": [[[7.589222823644128, 47.55704...
# 1  {"coordinates": [[[7.607734652244866, 47.56154...
# 2  {"coordinates": [[[7.604715401665313, 47.56534...
# 3  {"coordinates": [[[7.583750231201226, 47.54393...
# 5  {"coordinates": [[[7.564610400828693, 47.54703...
#
#                               Geo Point Erstmals erwähnt Amtlich benannt  \
# 0  47.55696838858744,7.5899914931669015             1243            1861
# 1   47.56234486059627,7.607345597795069              NaN            1944
# 2   47.56614109591284,7.603959599528592             1820            1906
# 3   47.54423016221659,7.583998938529825              NaN            1889
# 5   47.54914616103737,7.562775685140727              NaN            1898
#
#   Indextext            Kurztext
# 0       SCH       Schlüsselberg
# 1       KIE        Kienbergstr.
# 2       SAN      Sandgrubenstr.
# 3       REI  Reichensteinerstr.
# 5       GOT        Gotthardstr.

# %% [markdown]
# **💡 Erkenntnis**
# Es gibt zu viele Objekt mit einer Jahreszahl

# %% [markdown]
# Versuch nach den Texten zu suchen, die in `Erklärung erste Zeile` einen Ziffer und anschliessend ein `-` (En Dash, Unicode: U+2013) aufweisen

# %%
dfnumber = a[a["Erklärung erste Zeile"].str.contains('[0-9]–')]
dfnumber.head(5)
# Out:
#     Id Strasse                Strassenname  \
# 26         627                 Wallstrasse
# 27         660              Zwingerstrasse
# 28         120    Daniel Fechter-Promenade
# 32         661  Friedrich Miescher-Strasse
# 47         147          Emil Angst-Strasse
#
#                          Erklärung erste Zeile  \
# 26                    Wall, Teil der 1859–1878
# 27                Theodor Zwinger (1533–1588),
# 28          Daniel Albert Fechter (1805–1876),
# 32  Friedrich Miescher (1844–1895), Mediziner,
# 47                     Emil Angst (1861–1941),
#
#                                Erklärung zweite Zeile  \
# 26                      abgetragenen Stadtbefestigung
# 27                        Arzt und Universalgelehrter
# 28  Lokalhistoriker, erster Basler Strassennamenfo...
# 32      Zellkernforscher, Entdecker der Nukleinsäuren
# 47             Politiker, Lehrer und Genossenschafter
#
#                                             Geo Shape  \
# 26  {"coordinates": [[[7.588986935147142, 47.55017...
# 27  {"coordinates": [[7.593796395226887, 47.544954...
# 28  {"coordinates": [[[7.596007858759982, 47.53294...
# 32  {"coordinates": [[7.564820619486617, 47.573896...
# 47  {"coordinates": [[[7.603258581899125, 47.53131...
#
#                                Geo Point Erstmals erwähnt Amtlich benannt  \
# 26   47.55034565110816,7.589412843688632             1610            1861
# 27  47.544216908270066,7.593255463957239             1905            1912
# 28  47.531446924918995,7.595551798612379             1922            1935
# 32  47.572725336470974,7.563001055009233              NaN            1968
# 47   47.53115025344692,7.602878868374037              NaN            1944
#
#    Indextext                 Kurztext
# 26       WAL                 Wallstr.
# 27       ZWI              Zwingerstr.
# 28       FEC     Daniel Fechter-Prom.
# 32       MIE  Friedrich Miescher-Str.
# 47       ANG          Emil Angst-Str.

# %%
dfnumber.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 147 entries, 26 to 1425
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Id Strasse              147 non-null    int64
#  1   Strassenname            147 non-null    object
#  2   Erklärung erste Zeile   147 non-null    object
#  3   Erklärung zweite Zeile  119 non-null    object
#  4   Geo Shape               147 non-null    object
#  5   Geo Point               147 non-null    object
#  6   Erstmals erwähnt        33 non-null     object
#  7   Amtlich benannt         147 non-null    object
#  8   Indextext               147 non-null    object
#  9   Kurztext                147 non-null    object
# dtypes: int64(1), object(9)
# memory usage: 12.6+ KB

# %% [markdown]
# ----
# ### Namen extrahieren
# Gemäss dp-StrassenBS-Wikidata.ipynb

# %%
seperators =["strasse", "-Strasse", "weg", "-Weg", "-Anlage", "anlage", "-Promenade", "rain", "gasse", "gässlein", "gässchen",
             "-Steg", "platz", "-Platz", "-Brücke", "-Passage", "graben", "-Graben", "steg", "-Park", "park", "schanze", "tunnel", "kreisel", "ring", "allee"]

# %%
import numpy as np

dfnumberStam = dfnumber.copy() #Sonst gibt es eine Warnung beim setzen der neuen Spalte
dfnumberStam["Stamm"] = dfnumberStam["Strassenname"]
dfnumberStam["suffix"] = np.nan

dfnumberStam.head(3)
# Out:
#     Id Strasse              Strassenname               Erklärung erste Zeile  \
# 26         627               Wallstrasse            Wall, Teil der 1859–1878
# 27         660            Zwingerstrasse        Theodor Zwinger (1533–1588),
# 28         120  Daniel Fechter-Promenade  Daniel Albert Fechter (1805–1876),
#
#                                Erklärung zweite Zeile  \
# 26                      abgetragenen Stadtbefestigung
# 27                        Arzt und Universalgelehrter
# 28  Lokalhistoriker, erster Basler Strassennamenfo...
#
#                                             Geo Shape  \
# 26  {"coordinates": [[[7.588986935147142, 47.55017...
# 27  {"coordinates": [[7.593796395226887, 47.544954...
# 28  {"coordinates": [[[7.596007858759982, 47.53294...
#
#                                Geo Point Erstmals erwähnt Amtlich benannt  \
# 26   47.55034565110816,7.589412843688632             1610            1861
# 27  47.544216908270066,7.593255463957239             1905            1912
# 28  47.531446924918995,7.595551798612379             1922            1935
#
#    Indextext              Kurztext                     Stamm  suffix
# 26       WAL              Wallstr.               Wallstrasse     NaN
# 27       ZWI           Zwingerstr.            Zwingerstrasse     NaN
# 28       FEC  Daniel Fechter-Prom.  Daniel Fechter-Promenade     NaN

# %%
for seperator in seperators:

    seriesnumberStam1 = dfnumberStam.Strassenname.str.removesuffix(seperator)
    dfnumberStam2 = pd.DataFrame(seriesnumberStam1)
    dfnumberStam2.rename(columns = {"Strassenname":"temp"}, inplace = True)

    dfnumberStam = pd.concat([dfnumberStam, dfnumberStam2], axis=1)

    dfnumberStam['suffix'] = np.where(dfnumberStam["Strassenname"] != dfnumberStam["temp"], seperator, dfnumberStam["suffix"])
    dfnumberStam['Stamm'] = np.where(dfnumberStam['Strassenname'] != dfnumberStam['temp'], dfnumberStam['temp'], dfnumberStam['Stamm'])

    del dfnumberStam['temp']

# %%
dfnumberStam.head()
# Out:
#     Id Strasse                Strassenname  \
# 26         627                 Wallstrasse
# 27         660              Zwingerstrasse
# 28         120    Daniel Fechter-Promenade
# 32         661  Friedrich Miescher-Strasse
# 47         147          Emil Angst-Strasse
#
#                          Erklärung erste Zeile  \
# 26                    Wall, Teil der 1859–1878
# 27                Theodor Zwinger (1533–1588),
# 28          Daniel Albert Fechter (1805–1876),
# 32  Friedrich Miescher (1844–1895), Mediziner,
# 47                     Emil Angst (1861–1941),
#
#                                Erklärung zweite Zeile  \
# 26                      abgetragenen Stadtbefestigung
# 27                        Arzt und Universalgelehrter
# 28  Lokalhistoriker, erster Basler Strassennamenfo...
# 32      Zellkernforscher, Entdecker der Nukleinsäuren
# 47             Politiker, Lehrer und Genossenschafter
#
#                                             Geo Shape  \
# 26  {"coordinates": [[[7.588986935147142, 47.55017...
# 27  {"coordinates": [[7.593796395226887, 47.544954...
# 28  {"coordinates": [[[7.596007858759982, 47.53294...
# 32  {"coordinates": [[7.564820619486617, 47.573896...
# 47  {"coordinates": [[[7.603258581899125, 47.53131...
#
#                                Geo Point Erstmals erwähnt Amtlich benannt  \
# 26   47.55034565110816,7.589412843688632             1610            1861
# 27  47.544216908270066,7.593255463957239             1905            1912
# 28  47.531446924918995,7.595551798612379             1922            1935
# 32  47.572725336470974,7.563001055009233              NaN            1968
# 47   47.53115025344692,7.602878868374037              NaN            1944
#
#    Indextext                 Kurztext               Stamm      suffix
# 26       WAL                 Wallstr.                Wall     strasse
# 27       ZWI              Zwingerstr.             Zwinger     strasse
# 28       FEC     Daniel Fechter-Prom.      Daniel Fechter  -Promenade
# 32       MIE  Friedrich Miescher-Str.  Friedrich Miescher    -Strasse
# 47       ANG          Emil Angst-Str.          Emil Angst    -Strasse

# %% [markdown]
# #### Mit Wikidata abgleichen

# %%
from SPARQLWrapper import SPARQLWrapper, JSON
wdUrl = "https://query.wikidata.org/sparql"
sparql = SPARQLWrapper(wdUrl)

# %%
def queryWd(sparql, subject):
    #print(wdKey)
    query = """
    SELECT ?subject ?subjectLabel ?instanceLabel WHERE {
      # ?subject rdfs:label "%s"@de;
               wdt:P31 ?instance.
      SERVICE wikibase:label { bd:serviceParam wikibase:language "de" . }   
    }
    """ % (subject)
    #print(query)
    
    sparql.setQuery(query)
    sparql.setReturnFormat(JSON)
    return sparql

# %%
import time, sys
from IPython.display import clear_output

def update_progress(progress):
    bar_length = 20
    if isinstance(progress, int):
        progress = float(progress)
    if not isinstance(progress, float):
        progress = 0
    if progress < 0:
        progress = 0
    if progress >= 1:
        progress = 1

    block = int(round(bar_length * progress))

    clear_output(wait = True)
    text = "Progress: [{0}] {1:.1f}%".format( "#" * block + "-" * (bar_length - block), progress * 100)
    print(text)

# %%
from time import sleep

i = 0
total = int(len(dfnumberStam.index))
dfr = pd.DataFrame(columns=["Name", "wikiQLabel", "wikiQ", "instance"])

maxresults = 10

for x in dfnumberStam.index:
    i+=1
    #print(i)
    subject = dfnumberStam['Stamm'][x]
    subjectStr = dfnumberStam['Strassenname'][x]
    #print(f"Subjekt: {subject}")
    sparql = queryWd(sparql, subject)
    update_progress(i / total)
    try:
        results = sparql.query()
        #print(results.info())
        
    except Exception as e:
        print(f"{i} Anfragen bis jetzt")
        #Prüfen auf Statuscode 429 (Too many Requests)
        if e.status == 429:
            print(f'Statuscode 429 aufgetreten: Anfrage geht in {e.headers.get("retry-after")}sec weiter')
            sleep(int(e.headers.get("retry-after"))+2)


    result = results.convert()
    #print(result)

    results_df = pd.json_normalize(result['results']['bindings'])
    #print(results_df)

    if not results_df.empty:
        wikiQ = results_df['subject.value'][0]
        wikiQLabel = results_df['subjectLabel.value'][0]
        instance = results_df['instanceLabel.value'][0]

        #print(f"{subjectStr} | {wikiQLabel}: {wikiQ} -> {instance}")
        dfrtemp = pd.DataFrame([[subjectStr, wikiQLabel, wikiQ, instance]], columns=dfr.columns)
        dfr = pd.concat([dfr, dfrtemp])

    else:
        #print(f"{subjectStr} | {subject}: Kein Eintrag in Wikidata gefunden")
        dfrtemp = pd.DataFrame([[subjectStr, subject, np.nan, np.nan]], columns=dfr.columns)
        dfr = pd.concat([dfr, dfrtemp])

    #print(x)
    #if i > maxresults:
        #break
# Out:
# Progress: [####################] 100.0%

# %%
dfr.head()
# Out:
#                          Name          wikiQLabel  \
# 0                 Wallstrasse                Wall
# 0              Zwingerstrasse             Zwinger
# 0    Daniel Fechter-Promenade      Daniel Fechter
# 0  Friedrich Miescher-Strasse  Friedrich Miescher
# 0          Emil Angst-Strasse          Emil Angst
#
#                                      wikiQ                 instance
# 0  http://www.wikidata.org/entity/Q1182629  Borough in Pennsylvania
# 0   http://www.wikidata.org/entity/Q155107                   Palast
# 0                                      NaN                      NaN
# 0   http://www.wikidata.org/entity/Q116072                   Mensch
# 0                                      NaN                      NaN

# %%
n = dfr.groupby("instance").nunique()

# %%
print(n)
# Out:
#                                  Name  wikiQLabel  wikiQ
# instance
# Achterbahn                          1           1      1
# Album                               2           1      1
# Basler Quartiere                    5           2      2
# Borough in Pennsylvania             1           1      1
# City in den Vereinigten Staaten     1           1      1
# Familienname                        4           3      3
# Fluss                               1           1      1
# Mensch                             55          49     49
# Ortsteil                            1           1      1
# Palast                              1           1      1
# Regionalverband                     1           1      1
# Stadt                               1           1      1
# Straßenbrücke                       1           1      1
# Taxon                               1           1      1
# Turm                                1           1      1
# Warenhaus                           1           1      1
# Wikimedia-Begriffsklärungsseite    33          29     29
# abgeleitete SI-Einheit              1           1      1

# %% [markdown]
# Prüfen wieso in Namen mehr eindeutige Werte stehen als in wikiQLabel und wikiQ

# %%
t = dfr[dfr['instance'] == 'Album']

# %%
t.head()
# Out:
#            Name wikiQLabel                                   wikiQ instance
# 0    Voltaplatz      Volta  http://www.wikidata.org/entity/Q174563    Album
# 0  Voltastrasse      Volta  http://www.wikidata.org/entity/Q174563    Album

# %% [markdown]
# Von den potenziel 147 Menschen werden "nur" 55 also solche erkannt.
# Ein Problem ist unter anderem, dass Strassen ohne Vor- und Nachnamen überhaupt nicht erkannt werden.
# Versuch auch Personen von Strassen mit nur dem Nachnamen zu treffen.

# %%
dfnm = dfr[dfr['instance'] != 'Mensch'].reset_index(drop=True)

# %%
def queryWdMenschen(sparql, subject):
    #print(wdKey)
    query = """
    SELECT ?subject ?subjectLabel WHERE {
      # ?subject wdt:P734 ?familyname;
               wdt:P31 wd:Q5.
      # ?familyname rdfs:label "%s"@de;
      SERVICE wikibase:label { bd:serviceParam wikibase:language "de" . }   
    }
    """ % (subject)
    #print(query)
    
    sparql.setQuery(query)
    sparql.setReturnFormat(JSON)
    return sparql

# %%
from time import sleep

i = 0
total = int(len(dfnm.index))
dfr2 = pd.DataFrame(columns=["2Name", "2wikiQLabel", "2wikiQ"])

maxresults = 10

for x in dfnm.index:
    i+=1
    #print(i)
    subject = dfnm['wikiQLabel'][x]
    subjectStr = dfnm['Name'][x]
    #print(f"Subjekt: {subject}")
    sparql = queryWdMenschen(sparql, subject)
    update_progress(i / total)
    try:
        results = sparql.query()
        #print(results.info())
        
    except Exception as e:
        print(f"{i} Anfragen bis jetzt")
        #Prüfen auf Statuscode 429 (Too many Requests)
        if e.status == 429:
            print(f'Statuscode 429 aufgetreten: Anfrage geht in {e.headers.get("retry-after")}sec weiter')
            sleep(int(e.headers.get("retry-after"))+2)


    result = results.convert()
    #print(result)

    results_df = pd.json_normalize(result['results']['bindings'])
    #print(results_df)

    if not results_df.empty:
        wikiQ = results_df['subject.value'][0]
        wikiQLabel = results_df['subjectLabel.value'][0]

        #print(f"{subjectStr} | {wikiQLabel}: {wikiQ} -> {instance}")
        dfrtemp = pd.DataFrame([[subjectStr, wikiQLabel, wikiQ]], columns=dfr2.columns)
        dfr2 = pd.concat([dfr2, dfrtemp])

    else:
        #print(f"{subjectStr} | {subject}: Kein Eintrag in Wikidata gefunden")
        dfrtemp = pd.DataFrame([[subjectStr, subject, np.nan]], columns=dfr2.columns)
        dfr2 = pd.concat([dfr2, dfrtemp])

    #print(x)
    #if i > maxresults:
        #break

# %%
dfr2.head(10)
# Out:
#                       2Name                 2wikiQLabel  \
# 0               Wallstrasse                  Larry Wall
# 0            Zwingerstrasse  Theodor Zwinger der Ältere
# 0  Daniel Fechter-Promenade              Daniel Fechter
# 0        Emil Angst-Strasse                  Emil Angst
# 0                Brantgasse             Sebastian Brant
# 0      Mittlere Rheinbrücke        Mittlere Rheinbrücke
# 0              Eulerstrasse              Leonhard Euler
# 0              Socinstrasse                Albert Socin
# 0              Fatiostrasse                Victor Fatio
# 0           Schanzenstrasse                    Schanzen
#
#                                    2wikiQ
# 0   http://www.wikidata.org/entity/Q92597
# 0  http://www.wikidata.org/entity/Q116094
# 0                                     NaN
# 0                                     NaN
# 0   http://www.wikidata.org/entity/Q60351
# 0                                     NaN
# 0    http://www.wikidata.org/entity/Q7604
# 0   http://www.wikidata.org/entity/Q89647
# 0  http://www.wikidata.org/entity/Q114588
# 0                                     NaN

# %%
dfnan = dfr2[dfr2['2wikiQ'].isna()]

# %%
dfnan.head(5)
# Out:
#                       2Name           2wikiQLabel 2wikiQ
# 0  Daniel Fechter-Promenade        Daniel Fechter    NaN
# 0        Emil Angst-Strasse            Emil Angst    NaN
# 0      Mittlere Rheinbrücke  Mittlere Rheinbrücke    NaN
# 0           Schanzenstrasse              Schanzen    NaN
# 0           Im Schmiedenhof       Im Schmiedenhof    NaN

# %%
dfnan.to_csv("StrassenBSohneMenschzuweisung.csv")
