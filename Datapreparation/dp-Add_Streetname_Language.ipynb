# %% [markdown]
# # Add Language
#
# The csv-Data of [Amtliches Verzeichnis der Strassen](https://www.cadastre.ch/de/services/service/registry/street.html) does not contain information about the language of the streetname label. As this information are available on the Filegeodatabase of the Amtliches Verzeichnis der Strassen, this will be join with this notebook.

# %% [markdown]
# ---
# ## Donload and load with geopanda
# Download the Filegeodatabase and load the data with fiona in a geodataframe

# %%
import urllib.request
import pandas as pd
    
url = 'https://data.geo.admin.ch/ch.swisstopo.amtliches-strassenverzeichnis/gdb/2056/ch.swisstopo.amtliches-strassenverzeichnis.zip'
filehandle, _ = urllib.request.urlretrieve(url)

# %%
from zipfile import ZipFile

with ZipFile(filehandle, 'r') as zip:
    #zip.printdir()
    zip.extractall("pure_str")

# %%
import geopandas
pureStn = geopandas.read_file("pure_str/pure_str.gdb", layer="PURE_STN")

# %%
import shutil
shutil.rmtree("pure_str")

# %%
for layer in pureStn:
    print(layer)
# Out:
# STN_ID
# STR_ESID
# STN_TEXT
# STN_SHORT
# STN_INDEX
# STN_LANG
# geometry

# %%
pureStn.head()
# Out:
#      STN_ID    STR_ESID                 STN_TEXT                STN_SHORT  \
# 0  761294.0  10258316.0                  Eggwald                  Eggwald
# 1  469894.0  10023770.0                Wiedenweg                Wiedenweg
# 2  576880.0  10179192.0               Wuhrbärgli               Wuhrbärgli
# 3  747045.0  10250501.0  Hüethütte Unter Trübsee  Hüethütte Unter Trübsee
# 4  565831.0  10163108.0            Heimstenstich            Heimstenstich
#
#   STN_INDEX  STN_LANG geometry
# 0       Egg         0     None
# 1       Wie         0     None
# 2       Wuh         0     None
# 3       Hüe         0     None
# 4       Hei         0     None

# %%
pureStn.sort_values("STN_LANG")
# Out:
#           STN_ID    STR_ESID          STN_TEXT        STN_SHORT STN_INDEX  \
# 0       761294.0  10258316.0           Eggwald          Eggwald       Egg
# 143510  746750.0  10250271.0  Tüfenwiesstrasse    Tüfenwiesstr.       Tüf
# 143511  525093.0  10097218.0        Käsereiweg       Käsereiweg       Käs
# 143512  689689.0  10226376.0    Steinenbachweg   Steinenbachweg       Ste
# 143513  690232.0  10226919.0   Hirschenengasse  Hirschenengasse       Hir
# ...          ...         ...               ...              ...       ...
# 171976  761115.0  10258223.0         Via Cunel        Via Cunel       Cun
# 171978  761087.0  10258195.0      Via Cavorgia     Via Cavorgia       Cav
# 171979  761061.0  10258167.0       Via Vin Val      Via Vin Val       Vin
# 171965  761073.0  10258182.0     Via Scalinada    Via Scalinada       Sca
# 10100   602899.0  10149832.0       Via Ferrera      Via Ferrera       Fer
#
#         STN_LANG geometry
# 0              0     None
# 143510         0     None
# 143511         0     None
# 143512         0     None
# 143513         0     None
# ...          ...      ...
# 171976         3     None
# 171978         3     None
# 171979         3     None
# 171965         3     None
# 10100          3     None
#
# [221706 rows x 7 columns]

# %% [markdown]
# ---
# ## Create the lookup
# The Information about the Language are represented by numbers. The wil be replaced be language-code

# %%
STN_LANG = pureStn.STN_LANG.value_counts().reset_index()

STN_LANG.head()
# Out:
#    index  STN_LANG
# 0      0    165949
# 1      1     43434
# 2      2      9991
# 3      3      2332

# %%
pureStn.loc[pureStn['STN_LANG'] == 0, 'STN_LANG'] = 'de'
pureStn.loc[pureStn['STN_LANG'] == 1, 'STN_LANG'] = 'fr'
pureStn.loc[pureStn['STN_LANG'] == 2, 'STN_LANG'] = 'it'
pureStn.loc[pureStn['STN_LANG'] == 3, 'STN_LANG'] = 'rm'

# %%
pureStn.head()
# Out:
#      STN_ID    STR_ESID                 STN_TEXT                STN_SHORT  \
# 0  761294.0  10258316.0                  Eggwald                  Eggwald
# 1  469894.0  10023770.0                Wiedenweg                Wiedenweg
# 2  576880.0  10179192.0               Wuhrbärgli               Wuhrbärgli
# 3  747045.0  10250501.0  Hüethütte Unter Trübsee  Hüethütte Unter Trübsee
# 4  565831.0  10163108.0            Heimstenstich            Heimstenstich
#
#   STN_INDEX STN_LANG geometry
# 0       Egg       de     None
# 1       Wie       de     None
# 2       Wuh       de     None
# 3       Hüe       de     None
# 4       Hei       de     None

# %% [markdown]
# ---
# ## Join the language to streetnames.csv

# %%
streetnames = pd.read_csv('streetnames.csv', encoding='UTF-8-SIG', sep=';')

# %%
streetnames.head()
# Out:
#    Unnamed: 0  STR_ESID     STN_LABEL  COM_FOSNR     COM_NAME COM_CANTON  \
# 0           1  10023770     Wiedenweg       2786   Grellingen         BL
# 1           2  10179192    Wuhrbärgli       2788     Liesberg         BL
# 2           9  10140563  Emanuelenweg       2829      Liestal         BL
# 3          13  10069457       Löhrweg       2850  Känerkinden         BL
# 4          15  10096235    Brunngasse       2833   Seltisberg         BL
#
#    STR_OFFICIAL  STR_EASTING  STR_NORTHING STN_LABEL_NO_BI STN_LABEL_NO_TERMS  \
# 0          True    2610733.0     1254311.0       Wiedenweg             Wieden
# 1          True    2598709.0     1249640.0      Wuhrbärgli         Wuhrbärgli
# 2          True    2623078.0     1257558.0    Emanuelenweg          Emanuelen
# 3          True    2630229.0     1251411.0         Löhrweg               Löhr
# 4          True    2621406.0     1256852.0      Brunngasse              Brunn
#
#   STR_TERMS STR_PREPS STN_LABEL_FINAL
# 0       weg       NaN          Wieden
# 1       NaN       NaN      Wuhrbärgli
# 2       weg       NaN       Emanuelen
# 3       weg       NaN            Löhr
# 4     gasse       NaN           Brunn

# %%
streetnamesLangTemp = pureStn[["STR_ESID", "STN_LANG"]]

# %%
streetnamesLang = streetnames.join(streetnamesLangTemp.set_index('STR_ESID'), on='STR_ESID')

# %%
streetnamesLang.drop(["Unnamed: 0"], axis=1, inplace=True)

# %%
streetnamesLang.head()
# Out:
#    STR_ESID     STN_LABEL  COM_FOSNR     COM_NAME COM_CANTON  STR_OFFICIAL  \
# 0  10023770     Wiedenweg       2786   Grellingen         BL          True
# 1  10179192    Wuhrbärgli       2788     Liesberg         BL          True
# 2  10140563  Emanuelenweg       2829      Liestal         BL          True
# 3  10069457       Löhrweg       2850  Känerkinden         BL          True
# 4  10096235    Brunngasse       2833   Seltisberg         BL          True
#
#    STR_EASTING  STR_NORTHING STN_LABEL_NO_BI STN_LABEL_NO_TERMS STR_TERMS  \
# 0    2610733.0     1254311.0       Wiedenweg             Wieden       weg
# 1    2598709.0     1249640.0      Wuhrbärgli         Wuhrbärgli       NaN
# 2    2623078.0     1257558.0    Emanuelenweg          Emanuelen       weg
# 3    2630229.0     1251411.0         Löhrweg               Löhr       weg
# 4    2621406.0     1256852.0      Brunngasse              Brunn     gasse
#
#   STR_PREPS STN_LABEL_FINAL STN_LANG
# 0       NaN          Wieden       de
# 1       NaN      Wuhrbärgli       de
# 2       NaN       Emanuelen       de
# 3       NaN            Löhr       de
# 4       NaN           Brunn       de

# %%
streetnamesLang.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 172265 entries, 0 to 171878
# Data columns (total 14 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   STR_ESID            172265 non-null  int64
#  1   STN_LABEL           172265 non-null  object
#  2   COM_FOSNR           172265 non-null  int64
#  3   COM_NAME            172265 non-null  object
#  4   COM_CANTON          172265 non-null  object
#  5   STR_OFFICIAL        172265 non-null  bool
#  6   STR_EASTING         172265 non-null  float64
#  7   STR_NORTHING        172265 non-null  float64
#  8   STN_LABEL_NO_BI     172265 non-null  object
#  9   STN_LABEL_NO_TERMS  171391 non-null  object
#  10  STR_TERMS           140368 non-null  object
#  11  STR_PREPS           6818 non-null    object
#  12  STN_LABEL_FINAL     171079 non-null  object
#  13  STN_LANG            172265 non-null  object
# dtypes: bool(1), float64(2), int64(2), object(9)
# memory usage: 18.6+ MB

# %%
streetnamesLang.to_csv('streetnames.csv', encoding='UTF-8-SIG', sep=';')
